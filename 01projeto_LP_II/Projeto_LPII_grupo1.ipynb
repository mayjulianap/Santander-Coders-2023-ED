# %% [markdown]
# # Projeto Final - Sistema de Controle Financeiro
#
# ## Grupo 1
# * José Paulo Marchezi
# * Renato Freitas
# * Nicolas Evilasio
# * Mayra Juliana Pereira Alves
# * Rafael Gustavo Leite
# * Alexandre Sá Freire Brandão

# %% [markdown]
# # Fin-Ada

# %% [markdown]
# ## Importar modulos
#
# No momento que importamos as funções, os arquivos para armazenamenbto das movimentações e investimetos são criados.

# %%
from src.utils.funcoes import *
# Out:
# /Users/jose/python_projects/Santander-Coders-2023-ED/projeto_LPII

# %% [markdown]
# Parametros "fixos" de configuração:
# * PATH: informa o diretório onde os dados serão armazenados
# * TAXA_INVESTIMENTO: Valor utilizado no calculo do rentimento.

# %%
PATH = "./database"
TAXA_INVESTIMENTO = 0.0001

# %% [markdown]
# ## Iniciar Base de dados
#
# Criamos uma função para incluir e gerar a nosa base de dados. Essa base é constituida de dois arquivos:
#
# * "investimentos.csv"
#   - Armazena as entradas de investimentos
# * "movimentacoes.csv"
#   - Armazena as entradas de receita e despesas da conta
#
# Essa função oferece ao usuário duas opções para inclusão manual dos dados:
#
# 1. usuário informa a data (no formato ano-mes-dia); o valor; e tipo (investimento, receita, ou despesa).
#
# 2. a entradas serão lidas de um arquivo .csv, o usuario deve informar o nome desse arquivo.

# %%
# nome csv : financas_aleatorias_20_linhas.csv
incluir_registros_base_dados(taxa=TAXA_INVESTIMENTO, path=PATH)
# incluir_registros_base_dados(taxa=TAXA_INVESTIMENTO, path=PATH, nome_arquivo="financas_aleatorias_20_linhas.csv")
# Out:
# Como você deseja incluir os registros?
#
#                     1. Adicionar manualmente
#                     2. Importar Base CSV
#                     9. Retornar ao menu principal
#                     0. Sair do programa
# sh: cls: command not found
# investimento
# Registro [['0000001', 'investimento', 1882.0, 0.0001, 2023, 1, 1, 0, 0]] inserido com sucesso no arquivo ./database/investimentos.csv
# receita
# Registro [['0000001', 'receita', 4787.0, 2023, 1, 18]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# investimento
# Registro [['0000002', 'investimento', 1574.0, 0.0001, 2023, 1, 27, 0, 0]] inserido com sucesso no arquivo ./database/investimentos.csv
# despesa
# Registro [['0000002', 'despesa', -101.0, 2023, 2, 23]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000003', 'despesa', -6941.0, 2023, 2, 28]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# receita
# Registro [['0000004', 'receita', 3674.0, 2023, 4, 9]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# investimento
# Registro [['0000003', 'investimento', 9072.0, 0.0001, 2023, 4, 14, 0, 0]] inserido com sucesso no arquivo ./database/investimentos.csv
# investimento
# Registro [['0000004', 'investimento', 8210.0, 0.0001, 2023, 5, 28, 0, 0]] inserido com sucesso no arquivo ./database/investimentos.csv
# investimento
# Registro [['0000005', 'investimento', 988.0, 0.0001, 2023, 6, 9, 0, 0]] inserido com sucesso no arquivo ./database/investimentos.csv
# receita
# Registro [['0000005', 'receita', 5423.0, 2023, 6, 14]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# receita
# Registro [['0000006', 'receita', 2340.0, 2023, 6, 21]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000007', 'despesa', -861.0, 2023, 7, 26]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000008', 'despesa', -5815.0, 2023, 8, 9]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# receita
# Registro [['0000009', 'receita', 1040.0, 2023, 9, 4]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000010', 'despesa', -2702.0, 2023, 9, 15]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000011', 'despesa', -8255.0, 2023, 11, 8]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000012', 'despesa', -6151.0, 2023, 11, 14]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# despesa
# Registro [['0000013', 'despesa', -3035.0, 2023, 12, 4]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# receita
# Registro [['0000014', 'receita', 1252.0, 2023, 12, 13]] inserido com sucesso no arquivo ./database/movimentacoes.csv
# investimento
# Registro [['0000006', 'investimento', 1063.0, 0.0001, 2023, 12, 16, 0, 0]] inserido com sucesso no arquivo ./database/investimentos.csv
# Calculando rendimento dos investimentos...
# Rendimento dos investimentos atualizados com sucesso!
# Registros inseridos com sucesso.
# Como você deseja incluir os registros?
#
#                     1. Adicionar manualmente
#                     2. Importar Base CSV
#                     9. Retornar ao menu principal
#                     0. Sair do programa
#
# Saindo do programa.

# %% [markdown]
# ## Agrupar dados

# %%
movimentacoes = read_csv(f"{PATH}/movimentacoes.csv")
print(agrupar_movimentacoes(movimentacoes, agrupar_por="tipo"))
print(agrupar_movimentacoes(movimentacoes, agrupar_por="mes"))

investimentos = read_csv(f"{PATH}/investimentos.csv")
print(agrupar_movimentacoes(investimentos, agrupar_por="tipo"))
print(agrupar_movimentacoes(investimentos, agrupar_por="ano"))
# Out:
# {'receita': 18516.0, 'despesa': -33861.0}
# {'valor_mes_1': 4787.0, 'valor_mes_2': -7042.0, 'valor_mes_4': 3674.0, 'valor_mes_6': 7763.0, 'valor_mes_7': -861.0, 'valor_mes_8': -5815.0, 'valor_mes_9': -1662.0, 'valor_mes_11': -14406.0, 'valor_mes_12': -1783.0}
# {'investimento': 71980.038}
# {'valor_ano_2023': 71980.038}

# %% [markdown]
# ## Atualizar registro

# %%
movimentacoes = read_csv(f"{PATH}/movimentacoes.csv")
movimentacoes[3]
# Out:
# {'id': '0000004',
#  'tipo': 'receita',
#  'valor': '3674.0',
#  'ano': '2023',
#  'mes': '4',
#  'dia': '9'}

# %%
atualizar_registro(indice=4,
                       tipo="despesa",
                       database_path=PATH,
                       valor=13)
# Out:
# Registro 4 atualizado para {'id': '0000004', 'tipo': 'receita', 'valor': -13, 'ano': '2023', 'mes': '4', 'dia': '9'} com sucesso!

# %%
movimentacoes = read_csv(f"{PATH}/movimentacoes.csv")
movimentacoes[3]
# Out:
# {'id': '0000004',
#  'tipo': 'receita',
#  'valor': '-13',
#  'ano': '2023',
#  'mes': '4',
#  'dia': '9'}

# %%
investimentos = read_csv(f"{PATH}/investimentos.csv")
investimentos[3]
# Out:
# {'id': '0000004',
#  'tipo': 'investimento',
#  'capital': '8210.0',
#  'taxa': '0.0001',
#  'ano': '2023',
#  'mes': '5',
#  'dia': '28',
#  'montante': '18868.166',
#  'rendimento': '46.943'}

# %%
atualizar_registro(indice=4,
                       tipo="investimento",
                       database_path=PATH,
                       valor=13,
                       taxa=TAXA_INVESTIMENTO)
# Out:
# Registro 4 atualizado para {'id': '0000004', 'tipo': 'investimento', 'capital': 13, 'taxa': 0.0001, 'ano': '2023', 'mes': '5', 'dia': '28', 'montante': '18868.166', 'rendimento': '46.943'} com sucesso!
# Calculando rendimento dos investimentos...
# Rendimento dos investimentos atualizados com sucesso!

# %%
investimentos = read_csv(f"{PATH}/investimentos.csv")
investimentos[3]
# Out:
# {'id': '0000004',
#  'tipo': 'investimento',
#  'capital': '13',
#  'taxa': '0.0001',
#  'ano': '2023',
#  'mes': '5',
#  'dia': '28',
#  'montante': '10671.166',
#  'rendimento': '46.943'}

# %% [markdown]
# ## Exportar os dados

# %%
movimentacoes = read_csv(f"{PATH}/movimentacoes.csv")
exportar_relatorio_json(movimentacoes, formato='json', nome_arquivo='relatorio_movimentacoes')
investimentos = read_csv(f"{PATH}/investimentos.csv")
exportar_relatorio_json(investimentos, formato='csv', nome_arquivo='relatorio_investimentos')
# Out:
# Relatorio relatorio_movimentacoes exportado com sucesso!
# Relatorio relatorio_investimentos exportado com sucesso!

# %% [markdown]
# ## Detelar registro

# %%
deletar_registro(indice=3, tipo="despesa", database_path=PATH)
# Out:
# Registro 3 não encontrado.
